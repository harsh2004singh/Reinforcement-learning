# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Harsh\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
import matplotlib.pyplot as plt

# %%
X= np.random.rand(100,1)*10
y= 3*X.squeeze()+5+ np.random.randn(100)

# %%
X,y
# Out:
# (array([[8.06691326],
#         [2.99973557],
#         [0.52028923],
#         [1.9051332 ],
#         [7.96733175],
#         [6.79884455],
#         [4.28505406],
#         [6.95607643],
#         [7.46562548],
#         [4.06641505],
#         [0.62495176],
#         [3.54393384],
#         [8.97946931],
#         [2.18968207],
#         [9.25305517],
#         [5.07674889],
#         [0.67332987],
#         [1.73569768],
#         [1.7042991 ],
#         [3.56427969],
#         [9.25573176],
#         [0.04312573],
#         [1.86473174],
#         [9.50710999],
#         [4.55456559],
#         [8.4847742 ],
#         [3.1868    ],
#         [6.21953937],
#         [3.47674484],
#         [8.12819468],
#         [7.93018161],
#         [4.65343237],
#         [3.58293733],
#         [0.50734695],
#         [8.72626735],
#         [3.62008485],
#         [3.43273893],
#         [4.50243445],
#         [3.36652897],
#         [9.45027448],
#         [7.64885264],
#         [0.04721954],
#         [8.33365418],
#         [8.3126217 ],
#         [9.92222487],
#         [2.22290258],
#         [5.80908823],
#         [3.18530074],
#         [9.92247835],
#         [0.06336307],
#         [2.37755701],
#         [4.62212702],
#         [3.73034792],
#         [6.306397  ],
#         [6.05340958],
#         [2.32862161],
#         [5.15876076],
#         [0.34005593],
#         [4.59823556],
#         [7.57496619],
#         [6.00937223],
#         [7.61835594],
#         [7.0882322 ],
#         [9.46364659],
#         [5.90407946],
#         [1.35108778],
#         [5.64736363],
#         [0.3969308 ],
#         [3.20450936],
#         [4.01200808],
#         [3.96195554],
#         [0.24342362],
#         [1.52481658],
#         [5.51818808],
#         [4.81203546],
#         [2.77229613],
#         [5.95064378],
#         [8.09529975],
#         [3.40757483],
#         [3.55181818],
#         [3.30129014],
#         [8.12727955],
#         [6.88577307],
#         [4.60433933],
#         [9.9929252 ],
#         [6.95607755],
#         [1.43235546],
#         [7.4216602 ],
#         [1.68864111],
#         [4.84372085],
#         [5.78388483],
#         [5.93267608],
#         [8.5923787 ],
#         [2.58794964],
#         [2.53435574],
#         [1.36566054],
#         [9.6737509 ],
#         [1.47979479],
#         [2.819225  ],
#         [2.48510048]]),
#  array([28.79587763, 13.40234252,  7.04419808, 11.17547583, 29.1979322 ,
#         26.15218188, 19.46221636, 26.25364327, 26.41504153, 18.601313  ,
#          7.27947009, 15.67577436, 33.50732835, 13.24826201, 32.78080589,
#         18.92752632,  6.74098072, 10.08835909,  9.73236028, 18.09721473,
#         32.28061202,  4.5579392 , 10.78528994, 34.33235301, 18.4758287 ,
#         31.01386246, 15.46665595, 27.28922675, 15.0885393 , 29.37175516,
#         30.64142784, 18.86295545, 16.49406809,  6.01248177, 31.48577702,
#         14.71692896, 13.15424812, 16.86080067, 16.36783619, 32.92982628,
#         25.21714001,  3.64078864, 30.70999929, 29.56787535, 34.56827582,
#         12.06665155, 22.41698307, 15.95379277, 34.2083545 ,  5.03267013,
#         13.58510127, 18.35043701, 18.90193501, 23.37802446, 22.76347502,
#         13.25078782, 19.88705661,  6.86795419, 19.44562682, 27.98723273,
#         21.53599242, 28.05080792, 26.76892079, 33.9974873 , 23.95758778,
#          9.65564268, 21.33519325,  7.01910435, 12.57226451, 16.54270148,
#         17.14818747,  5.62304139, 10.4162359 , 22.16654206, 19.53406845,
#         12.60460435, 24.02219918, 28.28444105, 15.72286121, 16.3497468 ,
#         13.74620409, 29.09652523, 25.24285928, 17.57612283, 36.44637561,
#         26.38519932,  7.80338106, 27.47546497, 11.31700832, 19.77887965,
#         23.39696188, 22.17165731, 31.38715971, 12.47984691, 11.59271522,
#          9.14548845, 35.43762848,  9.94946755, 13.04770341, 12.52860486]))

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
print('linear Regression')
print('MSE:', mean_squared_error(y,y_pred))
print("R2 Scrore:", r2_score(y,y_pred))
# Out:
# linear Regression
# MSE: 1.0466383707796518
# R2 Scrore: 0.9860816831041783

# %%
print("Slope(m)=", model.coef_[0])
print("intercept(c)=", model.intercept_)
# Out:
# Slope(m)= 3.0165431683424444
# intercept(c)= 5.065180313343651

# %%
plt.scatter(X,y)
plt.plot(X,y_pred,linewidth =2)
plt.xlabel("random X variable")

plt.ylabel(" random Y varable")
plt.title("linear regression graph")
plt.grid(True)
plt.show()
